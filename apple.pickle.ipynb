# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import requests

url = "https://iex.lewagon.com/stable/stock/aapl/chart/3m"
api_data = requests.get(url).json()

# %%
apple_df=pd.DataFrame(api_data)
apple_df
# Out:
#      close     high      low     open   priceDate symbol     volume  \
# 0   180.95  181.780  179.260  181.030  2023-06-02   AAPL   61996913
# 1   179.58  184.951  178.035  182.630  2023-06-05   AAPL  121946497
# 2   179.21  180.120  177.430  179.965  2023-06-06   AAPL   64848374
# 3   177.82  181.210  177.320  178.440  2023-06-07   AAPL   61944615
# 4   180.57  180.840  177.460  177.895  2023-06-08   AAPL   50214881
# ..     ...      ...      ...      ...         ...    ...        ...
# 59  180.19  180.590  178.545  180.090  2023-08-28   AAPL   43820697
# 60  184.12  184.900  179.500  179.695  2023-08-29   AAPL   53003948
# 61  187.65  187.850  184.740  184.940  2023-08-30   AAPL   60813888
# 62  187.87  189.120  187.480  187.840  2023-08-31   AAPL   60794467
# 63  189.46  189.920  188.280  189.485  2023-09-01   AAPL   45766503
#
#                    id   key subkey  ...     uLow    uVolume    fOpen   fClose  \
# 0   HISTORICAL_PRICES  AAPL         ...  179.260   61996913  180.542  180.462
# 1   HISTORICAL_PRICES  AAPL         ...  178.035  121946497  182.138  179.096
# 2   HISTORICAL_PRICES  AAPL         ...  177.430   64848374  179.480  178.727
# 3   HISTORICAL_PRICES  AAPL         ...  177.320   61944615  177.959  177.341
# 4   HISTORICAL_PRICES  AAPL         ...  177.460   50214881  177.416  180.083
# ..                ...   ...    ...  ...      ...        ...      ...      ...
# 59  HISTORICAL_PRICES  AAPL         ...  178.545   43820697  180.090  180.190
# 60  HISTORICAL_PRICES  AAPL         ...  179.500   53003948  179.695  184.120
# 61  HISTORICAL_PRICES  AAPL         ...  184.740   60813888  184.940  187.650
# 62  HISTORICAL_PRICES  AAPL         ...  187.480   60794467  187.840  187.870
# 63  HISTORICAL_PRICES  AAPL         ...  188.280   45766503  189.485  189.460
#
#       fHigh     fLow    fVolume       label  change  changePercent
# 0   181.290  178.777   61996913   Jun 2, 23    0.00         0.0000
# 1   184.453  177.555  121946497   Jun 5, 23   -1.37        -0.0076
# 2   179.635  176.952   64848374   Jun 6, 23   -0.37        -0.0021
# 3   180.722  176.842   61944615   Jun 7, 23   -1.39        -0.0078
# 4   180.353  176.982   50214881   Jun 8, 23    2.75         0.0155
# ..      ...      ...        ...         ...     ...            ...
# 59  180.590  178.545   43820697  Aug 28, 23    1.58         0.0088
# 60  184.900  179.500   53003948  Aug 29, 23    3.93         0.0218
# 61  187.850  184.740   60813888  Aug 30, 23    3.53         0.0192
# 62  189.120  187.480   60794467  Aug 31, 23    0.22         0.0012
# 63  189.920  188.280   45766503   Sep 1, 23    1.59         0.0085
#
# [64 rows x 27 columns]

# %%
apple_df['date'] = pd.to_datetime(apple_df['date'], format="%Y-%m-%d")

# %%
apple_df = apple_df.set_index('date')
apple_df
# Out:
#              close     high      low     open   priceDate symbol     volume  \
# date
# 2023-06-02  180.95  181.780  179.260  181.030  2023-06-02   AAPL   61996913
# 2023-06-05  179.58  184.951  178.035  182.630  2023-06-05   AAPL  121946497
# 2023-06-06  179.21  180.120  177.430  179.965  2023-06-06   AAPL   64848374
# 2023-06-07  177.82  181.210  177.320  178.440  2023-06-07   AAPL   61944615
# 2023-06-08  180.57  180.840  177.460  177.895  2023-06-08   AAPL   50214881
# ...            ...      ...      ...      ...         ...    ...        ...
# 2023-08-28  180.19  180.590  178.545  180.090  2023-08-28   AAPL   43820697
# 2023-08-29  184.12  184.900  179.500  179.695  2023-08-29   AAPL   53003948
# 2023-08-30  187.65  187.850  184.740  184.940  2023-08-30   AAPL   60813888
# 2023-08-31  187.87  189.120  187.480  187.840  2023-08-31   AAPL   60794467
# 2023-09-01  189.46  189.920  188.280  189.485  2023-09-01   AAPL   45766503
#
#                            id   key subkey  ...     uLow    uVolume    fOpen  \
# date                                        ...
# 2023-06-02  HISTORICAL_PRICES  AAPL         ...  179.260   61996913  180.542
# 2023-06-05  HISTORICAL_PRICES  AAPL         ...  178.035  121946497  182.138
# 2023-06-06  HISTORICAL_PRICES  AAPL         ...  177.430   64848374  179.480
# 2023-06-07  HISTORICAL_PRICES  AAPL         ...  177.320   61944615  177.959
# 2023-06-08  HISTORICAL_PRICES  AAPL         ...  177.460   50214881  177.416
# ...                       ...   ...    ...  ...      ...        ...      ...
# 2023-08-28  HISTORICAL_PRICES  AAPL         ...  178.545   43820697  180.090
# 2023-08-29  HISTORICAL_PRICES  AAPL         ...  179.500   53003948  179.695
# 2023-08-30  HISTORICAL_PRICES  AAPL         ...  184.740   60813888  184.940
# 2023-08-31  HISTORICAL_PRICES  AAPL         ...  187.480   60794467  187.840
# 2023-09-01  HISTORICAL_PRICES  AAPL         ...  188.280   45766503  189.485
#
#              fClose    fHigh     fLow    fVolume       label  change  \
# date
# 2023-06-02  180.462  181.290  178.777   61996913   Jun 2, 23    0.00
# 2023-06-05  179.096  184.453  177.555  121946497   Jun 5, 23   -1.37
# 2023-06-06  178.727  179.635  176.952   64848374   Jun 6, 23   -0.37
# 2023-06-07  177.341  180.722  176.842   61944615   Jun 7, 23   -1.39
# 2023-06-08  180.083  180.353  176.982   50214881   Jun 8, 23    2.75
# ...             ...      ...      ...        ...         ...     ...
# 2023-08-28  180.190  180.590  178.545   43820697  Aug 28, 23    1.58
# 2023-08-29  184.120  184.900  179.500   53003948  Aug 29, 23    3.93
# 2023-08-30  187.650  187.850  184.740   60813888  Aug 30, 23    3.53
# 2023-08-31  187.870  189.120  187.480   60794467  Aug 31, 23    0.22
# 2023-09-01  189.460  189.920  188.280   45766503   Sep 1, 23    1.59
#
#             changePercent
# date
# 2023-06-02         0.0000
# 2023-06-05        -0.0076
# 2023-06-06        -0.0021
# 2023-06-07        -0.0078
# 2023-06-08         0.0155
# ...                   ...
# 2023-08-28         0.0088
# 2023-08-29         0.0218
# 2023-08-30         0.0192
# 2023-08-31         0.0012
# 2023-09-01         0.0085
#
# [64 rows x 26 columns]

# %%
apple_df['close'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
apple_df[['open', 'close', 'high', 'low']].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
apple_df[['open', 'close', 'high', 'low']].plot(figsize=(24,12))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from nbresult import ChallengeResult

result = ChallengeResult('apple',
    index_name=apple_df.index.name,
    index_type=apple_df.index.dtype,
    columns=apple_df.columns
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /Users/juancorrea/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/juancorrea/code/Juancorreav/02-Data-Toolkit/02-Data-Sourcing/data-stock-market-api/tests
# plugins: asyncio-0.19.0, anyio-3.6.2
# asyncio: mode=strict
# collecting ... collected 3 items
#
# test_apple.py::TestApple::test_apple_df_columns PASSED                   [ 33%]
# test_apple.py::TestApple::test_apple_df_index_is_timestamp PASSED        [ 66%]
# test_apple.py::TestApple::test_apple_df_index_name_is_date PASSED        [100%]
#
# ============================== 3 passed in 1.28s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/apple.pickle
#
# git commit -m 'Completed apple step'
#
# git push origin master
